# %% [markdown]
# # Gestión de Datos

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
# %ls
# Out:
#  00_00_binder.ipynb                     02_02_basic_math.ipynb
#  00_00_primer_pasos.ipynb              'BasicStuff (1).ipynb'
#  01_01_data_types.ipynb                 datasets/
#  01_02_read_iloc_unique_groupby.ipynb   lectData.ipynb
#  02_00_data_wrangling.ipynb             README.md
#  02_01_null_display.ipynb               requirements.txt

# %%
import pandas as pd

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
# se leen las primeras dos filas

# %%
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x = df.columns

# %%
type(x)
# Out:
# pandas.core.indexes.base.Index

# %%
# hay que hacerla lista

# %%
x = list(df.columns)
x.sort()
x
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
type(x)
# Out:
# list

# %% [markdown]
# # Selección de variables de interés

# %%
# usamos "iloc" y "loc"

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
# cuando queremos llamar solo una variable, solo se requiere 1 paréntesis de estos []

# %%
df['Age']
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
# cuando se quieren llamar 2 o más variables se necesita poner dos paréntesis de estos []

# %%
df[['Age','Height']]
# Out:
#     Age  Height
# 0    56   62.00
# 1    26   62.00
# 2    33   66.00
# 3    39   64.00
# 4    27   73.00
# 5    24   75.00
# 6    28   75.00
# 7    22   65.00
# 8    29   74.00
# 9    33   63.00
# 10   30   69.50
# 11   28   62.75
# 12   25   65.00
# 13   23   61.50
# 14   31   73.00
# 15   26   71.00
# 16   26   61.50
# 17   27   66.00
# 18   23   70.00
# 19   24   68.00
# 20   23   69.00
# 21   29   71.00
# 22   25   70.00
# 23   26   69.00
# 24   23   65.00

# %%
df[['Age','Height','CWDistance']].head(3)
# Out:
#    Age  Height  CWDistance
# 0   56    62.0          79
# 1   26    62.0          70
# 2   33    66.0          85

# %%
x = df['Age'].head(2)
x
# Out:
# 0    56
# 1    26
# Name: Age, dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
y = df[['Age']].head(2)
y
# Out:
#    Age
# 0   56
# 1   26

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
# la tabla en pyton se llama DataFrame

# %%
df[['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses']].head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 0   1   56      F            1       Y
# 1   2   26      F            1       Y

# %%
### síntasis de 'loc' :
### [row inicial:row final, col inicial:col final]
# nombres de las columnas y renglones

# %%
ndf = df.loc[:, :'Glasses']
ndf.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 0   1   56      F            1       Y
# 1   2   26      F            1       Y

# %%
# hay que recordar que para llamar una lista completa es [:] (de principio a fin)

# %%
### síntasis de 'loc' :
### [row inicial:row final, col inicial:col final]
# índices de las columnas y renglones

# %%
ndf = df.iloc[3:5, :5]
ndf.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 3   4   39      F            1       N
# 4   5   27      M            2       N
